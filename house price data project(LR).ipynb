# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("house_prices_practice.csv")

# %%
df
# Out:
#       Id  OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  \
# 0      1            7       1560           0         1658       1969
# 1      2            4       2827           2         1319       2012
# 2      3            8       3920           0          841       2010
# 3      4            5       3044           0         1058       1998
# 4      5            7        801           1         2428       2020
# ..   ...          ...        ...         ...          ...        ...
# 295  296            1       3495           1         1792       1954
# 296  297            5       3438           3         1266       2003
# 297  298            6       1992           0         1148       1996
# 298  299            3       3722           1         1407       1998
# 299  300            9       1667           0          988       1958
#
#      FullBath  BedroomAbvGr  LotArea  SalePrice
# 0           2             1     8059     177106
# ...

# %%
df.shape
# Out:
# (300, 10)

# %%
df.columns
# Out:
# Index(['Id', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF',
#        'YearBuilt', 'FullBath', 'BedroomAbvGr', 'LotArea', 'SalePrice'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Id  OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  FullBath  \
# 0   1            7       1560           0         1658       1969         2
# 1   2            4       2827           2         1319       2012         3
# 2   3            8       3920           0          841       2010         1
# 3   4            5       3044           0         1058       1998         0
# 4   5            7        801           1         2428       2020         0
#
#    BedroomAbvGr  LotArea  SalePrice
# 0             1     8059     177106
# 1             4    13530     301044
# 2             4     9010     360609
# 3             4    13207     240556
# 4             1     9117     193656

# %%
df.tail(5)
# Out:
#       Id  OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  \
# 295  296            1       3495           1         1792       1954
# 296  297            5       3438           3         1266       2003
# 297  298            6       1992           0         1148       1996
# 298  299            3       3722           1         1407       1998
# 299  300            9       1667           0          988       1958
#
#      FullBath  BedroomAbvGr  LotArea  SalePrice
# 295         2             5     4978     250604
# 296         0             1     9373     329906
# 297         1             1     7907     184623
# 298         1             1     8097     303345
# 299         2             1    14553     204982

# %%
df.sample(10)
# Out:
#       Id  OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  \
# 290  291            5       1384           1         1484       2006
# 104  105            8       3483           0         1612       1967
# 203  204            6       1456           2         2297       1958
# 136  137            9       3808           3         2110       1960
# 82    83            8       1181           0         1554       1986
# 275  276            1       2724           0          685       2005
# 225  226           10       3517           2         2165       1962
# 52    53            4       2029           3         2190       1981
# 95    96           10       1719           0         1793       1974
# 163  164            4       3459           0         1642       1974
#
#      FullBath  BedroomAbvGr  LotArea  SalePrice
# 290         3             4    14686     220557
# 104         1             4     8295     319876
# 203         3             2     2661     224163
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            300 non-null    int64
#  1   OverallQual   300 non-null    int64
#  2   GrLivArea     300 non-null    int64
#  3   GarageCars    300 non-null    int64
#  4   TotalBsmtSF   300 non-null    int64
#  5   YearBuilt     300 non-null    int64
#  6   FullBath      300 non-null    int64
#  7   BedroomAbvGr  300 non-null    int64
#  8   LotArea       300 non-null    int64
#  9   SalePrice     300 non-null    int64
# dtypes: int64(10)
# memory usage: 23.6 KB

# %%
# cleaned data it is, and from the above info our target will be salesprice

# %%
df.describe()
# Out:
#                Id  OverallQual    GrLivArea  GarageCars  TotalBsmtSF  \
# count  300.000000   300.000000   300.000000  300.000000   300.000000
# mean   150.500000     5.326667  2307.386667    1.330000  1468.796667
# std     86.746758     2.873001  1042.561303    1.109898   672.333705
# min      1.000000     1.000000   504.000000    0.000000   303.000000
# 25%     75.750000     3.000000  1392.250000    0.000000   903.000000
# 50%    150.500000     5.000000  2265.500000    1.000000  1502.000000
# 75%    225.250000     8.000000  3306.500000    2.000000  2129.500000
# max    300.000000    10.000000  3998.000000    3.000000  2492.000000
#
#          YearBuilt    FullBath  BedroomAbvGr       LotArea      SalePrice
# count   300.000000  300.000000    300.000000    300.000000     300.000000
# mean   1986.163333    1.523333      2.926667   8969.453333  252262.903333
# std      21.377089    1.131543      1.456604   3753.531132   74998.055214
# ...

# %%
df.drop(columns="Id",inplace=True)

# %%
sns.pairplot(df) # pairplot is used to check correlation btw columns the columns shouldnt be more correlated

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# salesprice= 0.75 can be omitted or dropped because its highly correlated

# %%
x=df.drop(columns="SalePrice")
y=df["SalePrice"]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.3,random_state=42) # 42 groups and they are fixed now

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (210, 8)
# (90, 8)
# (210,)
# (90,)

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
model=LR.fit(x_train,y_train)
model
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9771361644591586

# %%
MAE=mean_absolute_error(y_test,y_pred)
MSE=mean_squared_error(y_test,y_pred)
RMSE=root_mean_squared_error(y_test,y_pred)
print(MAE)
print(MSE)
print(RMSE)
# Out:
# 10059.028010243162
# 143634503.38844422
# 11984.761298767873

# %%
sns.distplot(y_pred,y_test,hist=False)
# Out:
# <Axes: ylabel='Density'>

# %%
# Normalization

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, Normalizer,maxabs_scaler

# %%
#MinMaxscaler
# method -1
scaler1=MinMaxScaler()

# %%
scaler1=scaler1.fit(x_train)

# %%
X_train=scaler1.transform(x_train)

# %%
X_train
# Out:
# array([[0.55555556, 0.13908804, 1.        , ..., 0.        , 0.75      ,
#         0.84708156],
#        [0.        , 0.01003728, 0.        , ..., 1.        , 1.        ,
#         0.44398918],
#        [0.66666667, 0.51964439, 0.66666667, ..., 1.        , 0.25      ,
#         0.3429455 ],
#        ...,
#        [0.22222222, 0.07370232, 0.33333333, ..., 0.66666667, 1.        ,
#         0.08218013],
#        [0.33333333, 0.20562088, 1.        , ..., 1.        , 1.        ,
#         0.34232702],
#        [0.66666667, 0.83252079, 0.        , ..., 0.66666667, 1.        ,
#         0.76095864]], shape=(210, 8))

# %%
pd.DataFrame(X_train)
# Out:
#             0         1         2         3         4         5     6  \
# 0    0.555556  0.139088  1.000000  0.279580  0.123288  0.000000  0.75
# 1    0.000000  0.010037  0.000000  0.900868  0.383562  1.000000  1.00
# 2    0.666667  0.519644  0.666667  0.467337  0.479452  1.000000  0.25
# 3    0.666667  0.757385  0.000000  0.756053  0.328767  1.000000  1.00
# 4    0.666667  0.907370  0.000000  0.237551  0.424658  0.333333  0.00
# ..        ...       ...       ...       ...       ...       ...   ...
# 205  0.555556  0.144537  0.666667  0.272727  0.191781  0.000000  0.75
# 206  0.444444  0.241468  0.333333  0.809045  0.013699  0.333333  0.00
# 207  0.222222  0.073702  0.333333  0.790315  0.547945  0.666667  1.00
# 208  0.333333  0.205621  1.000000  0.426222  0.493151  1.000000  1.00
# 209  0.666667  0.832521  0.000000  0.398812  0.493151  0.666667  1.00
#
#             7
# 0    0.847082
# 1    0.443989
# 2    0.342945
# 3    0.129107
# 4    0.774720
# ..        ...
# 205  0.616158
# ...

# %%
pd.DataFrame(X_train,columns=x_train.columns)
# Out:
#      OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  FullBath  \
# 0       0.555556   0.139088    1.000000     0.279580   0.123288  0.000000
# 1       0.000000   0.010037    0.000000     0.900868   0.383562  1.000000
# 2       0.666667   0.519644    0.666667     0.467337   0.479452  1.000000
# 3       0.666667   0.757385    0.000000     0.756053   0.328767  1.000000
# 4       0.666667   0.907370    0.000000     0.237551   0.424658  0.333333
# ..           ...        ...         ...          ...        ...       ...
# 205     0.555556   0.144537    0.666667     0.272727   0.191781  0.000000
# 206     0.444444   0.241468    0.333333     0.809045   0.013699  0.333333
# 207     0.222222   0.073702    0.333333     0.790315   0.547945  0.666667
# 208     0.333333   0.205621    1.000000     0.426222   0.493151  1.000000
# 209     0.666667   0.832521    0.000000     0.398812   0.493151  0.666667
#
#      BedroomAbvGr   LotArea
# 0            0.75  0.847082
# ...

# %%
# method-2
scaler1=MinMaxScaler()
x=scaler1.fit_transform(x_train)
X_train=pd.DataFrame(x,columns=x_train.columns)
X_train
# Out:
#      OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  FullBath  \
# 0       0.555556   0.139088    1.000000     0.279580   0.123288  0.000000
# 1       0.000000   0.010037    0.000000     0.900868   0.383562  1.000000
# 2       0.666667   0.519644    0.666667     0.467337   0.479452  1.000000
# 3       0.666667   0.757385    0.000000     0.756053   0.328767  1.000000
# 4       0.666667   0.907370    0.000000     0.237551   0.424658  0.333333
# ..           ...        ...         ...          ...        ...       ...
# 205     0.555556   0.144537    0.666667     0.272727   0.191781  0.000000
# 206     0.444444   0.241468    0.333333     0.809045   0.013699  0.333333
# 207     0.222222   0.073702    0.333333     0.790315   0.547945  0.666667
# 208     0.333333   0.205621    1.000000     0.426222   0.493151  1.000000
# 209     0.666667   0.832521    0.000000     0.398812   0.493151  0.666667
#
#      BedroomAbvGr   LotArea
# 0            0.75  0.847082
# ...

# %%
model1=LR.fit(X_train,y_train)
model1
# Out:
# LinearRegression()

# %%
X_test=scaler1.transform(x_test)
Y_pred=model1.predict(X_test)

# %%
score1=r2_score(Y_pred,y_test)
score1
# Out:
# 0.9779883719171789

# %%
MAE=mean_absolute_error(y_test,Y_pred)
MSE=mean_squared_error(y_test,Y_pred)
RMSE=root_mean_squared_error(y_test,Y_pred)
print(MAE)
print(MSE)
print(RMSE)
# Out:
# 10059.028010242619
# 143634503.3884647
# 11984.761298768728

# %%
# same steps for the following
# StandardScaler, RobustScaler, Normalizer,maxabs_scaler
# then by calculating mse,mae , rmse we can compare all the types of sclers whichever type has the min error that is mse, mae and rmse we can use that
